# %%
import pandas as pd
import numpy as np

# %%
edu = pd.read_csv('files/ch02/educ_figdp_1_Data.csv',
                 na_values=':',
                 usecols=['TIME', 'GEO', 'INDIC_ED', 'Value'])
edu
# Out:
#      TIME                            GEO  \
# 0    2000  European Union (28 countries)
# 1    2001  European Union (28 countries)
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# ..    ...                            ...
# 379  2007                        Finland
# 380  2008                        Finland
# 381  2009                        Finland
# 382  2010                        Finland
# 383  2011                        Finland
#
#                                               INDIC_ED  Value
# 0    Total public expenditure on education as % of ...    NaN
# 1    Total public expenditure on education as % of ...    NaN
# 2    Total public expenditure on education as % of ...   5.00
# 3    Total public expenditure on education as % of ...   5.03
# 4    Total public expenditure on education as % of ...   4.95
# ..                                                 ...    ...
# ...

# %%
edu.head()
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
#
#                                             INDIC_ED  Value
# 0  Total public expenditure on education as % of ...    NaN
# 1  Total public expenditure on education as % of ...    NaN
# 2  Total public expenditure on education as % of ...   5.00
# 3  Total public expenditure on education as % of ...   5.03
# 4  Total public expenditure on education as % of ...   4.95

# %%
edu.tail()
# Out:
#      TIME      GEO                                           INDIC_ED  Value
# 379  2007  Finland  Total public expenditure on education as % of ...   5.90
# 380  2008  Finland  Total public expenditure on education as % of ...   6.10
# 381  2009  Finland  Total public expenditure on education as % of ...   6.81
# 382  2010  Finland  Total public expenditure on education as % of ...   6.85
# 383  2011  Finland  Total public expenditure on education as % of ...   6.76

# %%
edu.describe()
# Out:
#               TIME       Value
# count   384.000000  361.000000
# mean   2005.500000    5.203989
# std       3.456556    1.021694
# min    2000.000000    2.880000
# 25%    2002.750000    4.620000
# 50%    2005.500000    5.060000
# 75%    2008.250000    5.660000
# max    2011.000000    8.810000

# %%
edu['Value']
# Out:
# 0       NaN
# 1       NaN
# 2      5.00
# 3      5.03
# 4      4.95
#        ...
# 379    5.90
# 380    6.10
# 381    6.81
# 382    6.85
# 383    6.76
# Name: Value, Length: 384, dtype: float64

# %%
edu[10:14]
# Out:
#     TIME                            GEO  \
# 10  2010  European Union (28 countries)
# 11  2011  European Union (28 countries)
# 12  2000  European Union (27 countries)
# 13  2001  European Union (27 countries)
#
#                                              INDIC_ED  Value
# 10  Total public expenditure on education as % of ...   5.41
# 11  Total public expenditure on education as % of ...   5.25
# 12  Total public expenditure on education as % of ...   4.91
# 13  Total public expenditure on education as % of ...   4.99

# %%
edu.loc[90:94, ['TIME', 'GEO']]
# Out:
#     TIME      GEO
# 90  2006  Belgium
# 91  2007  Belgium
# 92  2008  Belgium
# 93  2009  Belgium
# 94  2010  Belgium

# %%
edu[edu['Value'] > 6.5].head()
# Out:
#      TIME      GEO                                           INDIC_ED  Value
# 93   2009  Belgium  Total public expenditure on education as % of ...   6.57
# 94   2010  Belgium  Total public expenditure on education as % of ...   6.58
# 95   2011  Belgium  Total public expenditure on education as % of ...   6.55
# 120  2000  Denmark  Total public expenditure on education as % of ...   8.28
# 121  2001  Denmark  Total public expenditure on education as % of ...   8.44

# %%
edu[edu['TIME'] > 2006].tail()
# Out:
#      TIME      GEO                                           INDIC_ED  Value
# 379  2007  Finland  Total public expenditure on education as % of ...   5.90
# 380  2008  Finland  Total public expenditure on education as % of ...   6.10
# 381  2009  Finland  Total public expenditure on education as % of ...   6.81
# 382  2010  Finland  Total public expenditure on education as % of ...   6.85
# 383  2011  Finland  Total public expenditure on education as % of ...   6.76

# %%
edu[edu['Value'] > 6.8]
# Out:
#      TIME      GEO                                           INDIC_ED  Value
# 120  2000  Denmark  Total public expenditure on education as % of ...   8.28
# 121  2001  Denmark  Total public expenditure on education as % of ...   8.44
# 122  2002  Denmark  Total public expenditure on education as % of ...   8.44
# 123  2003  Denmark  Total public expenditure on education as % of ...   8.33
# 124  2004  Denmark  Total public expenditure on education as % of ...   8.43
# 125  2005  Denmark  Total public expenditure on education as % of ...   8.30
# 126  2006  Denmark  Total public expenditure on education as % of ...   7.97
# 127  2007  Denmark  Total public expenditure on education as % of ...   7.81
# 128  2008  Denmark  Total public expenditure on education as % of ...   7.68
# 129  2009  Denmark  Total public expenditure on education as % of ...   8.74
# 130  2010  Denmark  Total public expenditure on education as % of ...   8.81
# ...

# %%
edu[edu['Value'].isnull()]
# Out:
#      TIME                            GEO  \
# 0    2000  European Union (28 countries)
# 1    2001  European Union (28 countries)
# 36   2000       Euro area (18 countries)
# 37   2001       Euro area (18 countries)
# 48   2000       Euro area (17 countries)
# 49   2001       Euro area (17 countries)
# 60   2000       Euro area (15 countries)
# 72   2000       Euro area (13 countries)
# 84   2000                        Belgium
# 174  2006                         Greece
# 175  2007                         Greece
# 176  2008                         Greece
# 177  2009                         Greece
# 178  2010                         Greece
# 179  2011                         Greece
# 252  2000                     Luxembourg
# 260  2008                     Luxembourg
# 261  2009                     Luxembourg
# 262  2010                     Luxembourg
# 263  2011                     Luxembourg
# 342  2006                        Romania
# 344  2008                        Romania
# ...

# %%
edu.max(axis = 0)
# Out:
# TIME                                                     2011
# GEO                                                     Spain
# INDIC_ED    Total public expenditure on education as % of ...
# Value                                                    8.81
# dtype: object

# %%
edu.count()
# Out:
# TIME        384
# GEO         384
# INDIC_ED    384
# Value       361
# dtype: int64

# %%
edu['Value'].sum()
# Out:
# np.float64(1878.6399999999999)

# %%
edu['TIME'].min()
# Out:
# 2000

# %%
edu['TIME'].max()
# Out:
# 2011

# %%
print(f'Pandas max function: {edu['Value'].max()}')
# Out:
# Pandas max function: 8.81

# %%
print(f'Python max function: {max(edu['Value'])}')
# Out:
# Python max function: nan

# %%
s = edu['Value']/100

# %%
s.head()
# Out:
# 0       NaN
# 1       NaN
# 2    0.0500
# 3    0.0503
# 4    0.0495
# Name: Value, dtype: float64

# %%
s = edu['Value'].apply(np.sqrt)
s.tail()
# Out:
# 379    2.428992
# 380    2.469818
# 381    2.609598
# 382    2.617250
# 383    2.600000
# Name: Value, dtype: float64

# %%
s = edu['Value'].apply(lambda d: d**2)

# %%
s.head()
# Out:
# 0        NaN
# 1        NaN
# 2    25.0000
# 3    25.3009
# 4    24.5025
# Name: Value, dtype: float64

# %%
edu['ValueNorm'] = edu['Value'] / edu['Value'].max()
edu['Value'].tail()
# Out:
# 379    5.90
# 380    6.10
# 381    6.81
# 382    6.85
# 383    6.76
# Name: Value, dtype: float64

# %%
edu['ValueNorm'].tail()
# Out:
# 379    0.669694
# 380    0.692395
# 381    0.772985
# 382    0.777526
# 383    0.767310
# Name: ValueNorm, dtype: float64

# %%
edu[0:0]
# Out:
# Empty DataFrame
# Columns: [TIME, GEO, INDIC_ED, Value]
# Index: []

# %%
s = edu[edu['ValueNorm']==1]
s
# Out:
#      TIME      GEO                                           INDIC_ED  Value  \
# 130  2010  Denmark  Total public expenditure on education as % of ...   8.81
#
#      ValueNorm
# 130        1.0

# %%
edu.drop('ValueNorm', axis=1, inplace = False)
edu.head()
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
#
#                                             INDIC_ED  Value  ValueNorm
# 0  Total public expenditure on education as % of ...    NaN        NaN
# 1  Total public expenditure on education as % of ...    NaN        NaN
# 2  Total public expenditure on education as % of ...   5.00   0.567537
# 3  Total public expenditure on education as % of ...   5.03   0.570942
# 4  Total public expenditure on education as % of ...   4.95   0.561862

# %%
edu.drop('ValueNorm', axis = 1, inplace = True)
edu.head()
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
#
#                                             INDIC_ED  Value
# 0  Total public expenditure on education as % of ...    NaN
# 1  Total public expenditure on education as % of ...    NaN
# 2  Total public expenditure on education as % of ...   5.00
# 3  Total public expenditure on education as % of ...   5.03
# 4  Total public expenditure on education as % of ...   4.95

# %%
edu = pd.concat([edu, pd.DataFrame({'TIME': 2000, 'Value': 5.00, 'GEO': 'a'},
                                  index=[max(edu.index)+1])])
edu = pd.concat([edu, pd.DataFrame({'TIME':2100, 'Value':4.0, 'GEO': 'Bangladesh'}, index=[max(edu.index)+1])])
edu.tail()
# Out:
#        TIME         GEO                                           INDIC_ED  \
# 382  2010.0     Finland  Total public expenditure on education as % of ...
# 383  2011.0     Finland  Total public expenditure on education as % of ...
# 384  2000.0           a                                                NaN
# 385  2000.0           a                                                NaN
# 386  2100.0  Bangladesh                                                NaN
#
#      Value  Time
# 382   6.85   NaN
# 383   6.76   NaN
# 384   5.00   NaN
# 385   5.00   NaN
# 386   4.00   NaN

# %%
for i in range(2):
    edu.drop(max(edu.index), axis=0, inplace = True)
edu.tail()
# Out:
#        TIME      GEO                                           INDIC_ED  \
# 379  2007.0  Finland  Total public expenditure on education as % of ...
# 380  2008.0  Finland  Total public expenditure on education as % of ...
# 381  2009.0  Finland  Total public expenditure on education as % of ...
# 382  2010.0  Finland  Total public expenditure on education as % of ...
# 383  2011.0  Finland  Total public expenditure on education as % of ...
#
#      Value  Time
# 379   5.90   NaN
# 380   6.10   NaN
# 381   6.81   NaN
# 382   6.85   NaN
# 383   6.76   NaN

# %%
edu.drop(max(edu.index) , axis=0, inplace=True)
edu.tail()
# Out:
#      TIME      GEO                                           INDIC_ED  Value
# 379  2007  Finland  Total public expenditure on education as % of ...   5.90
# 380  2008  Finland  Total public expenditure on education as % of ...   6.10
# 381  2009  Finland  Total public expenditure on education as % of ...   6.81
# 382  2010  Finland  Total public expenditure on education as % of ...   6.85
# 383  2011  Finland  Total public expenditure on education as % of ...   6.76

# %%
eduDrop = edu.dropna(how = 'any', subset = ['Value'])
eduDrop.head()
# Out:
#    TIME                            GEO  \
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
# 5  2005  European Union (28 countries)
# 6  2006  European Union (28 countries)
#
#                                             INDIC_ED  Value
# 2  Total public expenditure on education as % of ...   5.00
# 3  Total public expenditure on education as % of ...   5.03
# 4  Total public expenditure on education as % of ...   4.95
# 5  Total public expenditure on education as % of ...   4.92
# 6  Total public expenditure on education as % of ...   4.91

# %%
eduFilled = edu.fillna(value = {'Value': 0})
eduFilled.head()
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
#
#                                             INDIC_ED  Value
# 0  Total public expenditure on education as % of ...   0.00
# 1  Total public expenditure on education as % of ...   0.00
# 2  Total public expenditure on education as % of ...   5.00
# 3  Total public expenditure on education as % of ...   5.03
# 4  Total public expenditure on education as % of ...   4.95

# %%
edu.sort_values(by = 'Value', ascending = False, inplace = True)

# %%
edu.head()
# Out:
#      TIME      GEO                                           INDIC_ED  Value
# 130  2010  Denmark  Total public expenditure on education as % of ...   8.81
# 131  2011  Denmark  Total public expenditure on education as % of ...   8.75
# 129  2009  Denmark  Total public expenditure on education as % of ...   8.74
# 122  2002  Denmark  Total public expenditure on education as % of ...   8.44
# 121  2001  Denmark  Total public expenditure on education as % of ...   8.44

# %%
edu.sort_values(by = 'Value', ascending = True, inplace = True)

# %%
edu.head()
# Out:
#      TIME         GEO                                           INDIC_ED  \
# 336  2000     Romania  Total public expenditure on education as % of ...
# 347  2011     Romania  Total public expenditure on education as % of ...
# 259  2007  Luxembourg  Total public expenditure on education as % of ...
# 337  2001     Romania  Total public expenditure on education as % of ...
# 340  2004     Romania  Total public expenditure on education as % of ...
#
#      Value
# 336   2.88
# 347   3.07
# 259   3.15
# 337   3.25
# 340   3.28

# %%
edu.sort_index(axis = 0, ascending = True, inplace = True)
edu.head()
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
#
#                                             INDIC_ED  Value
# 0  Total public expenditure on education as % of ...    NaN
# 1  Total public expenditure on education as % of ...    NaN
# 2  Total public expenditure on education as % of ...   5.00
# 3  Total public expenditure on education as % of ...   5.03
# 4  Total public expenditure on education as % of ...   4.95

# %%
group = edu[['Value', 'TIME']].groupby('TIME').mean()
group
# Out:
#            Value
# TIME
# 2000.0  4.917917
# 2001.0  5.085172
# 2002.0  5.125625
# 2003.0  5.142812
# 2004.0  5.067500
# 2005.0  5.091563
# 2006.0  5.129000
# 2007.0  4.998387
# 2008.0  5.266897
# 2009.0  5.603667
# 2010.0  5.549333
# 2011.0  5.443667

# %%
filtered_data = edu[edu['TIME']>2005]
filtered_data
# Out:
#        TIME                            GEO  \
# 6    2006.0  European Union (28 countries)
# 7    2007.0  European Union (28 countries)
# 8    2008.0  European Union (28 countries)
# 9    2009.0  European Union (28 countries)
# 10   2010.0  European Union (28 countries)
# ..      ...                            ...
# 379  2007.0                        Finland
# 380  2008.0                        Finland
# 381  2009.0                        Finland
# 382  2010.0                        Finland
# 383  2011.0                        Finland
#
#                                               INDIC_ED  Value  Time
# 6    Total public expenditure on education as % of ...   4.91   NaN
# 7    Total public expenditure on education as % of ...   4.92   NaN
# 8    Total public expenditure on education as % of ...   5.04   NaN
# 9    Total public expenditure on education as % of ...   5.38   NaN
# 10   Total public expenditure on education as % of ...   5.41   NaN
# ...

# %%
pivedu = pd.pivot_table(filtered_data, values = 'Value', index = 'GEO', columns = 'TIME')
pivedu.head()
# Out:
# TIME            2006.0  2007.0  2008.0  2009.0  2010.0  2011.0
# GEO
# Austria           5.40    5.33    5.47    5.98    5.91    5.80
# Belgium           5.98    6.00    6.43    6.57    6.58    6.55
# Bulgaria          4.04    3.88    4.44    4.58    4.10    3.82
# Cyprus            7.02    6.95    7.45    7.98    7.92    7.87
# Czech Republic    4.42    4.05    3.92    4.36    4.25    4.51

# %% [markdown]
# pivedu.loc[['Spain', 'Portugal'], [2006, 2011]]

# %% [markdown]
# pivedu = pivedu.drop([
#                     'European Union (25 countries)',
#                     'European Union (27 countries)',
#                     'European Union (28 countries)'
#                     ],
#                     axis = 0)

# %%
pivedu = pivedu.drop([
                    'Euro area (13 countries)',
                    'Euro area (15 countries)',
                    'Euro area (17 countries)',
                    'Euro area (18 countries)',
                ],
                    axis = 0)
pivedu = pivedu.rename(index = {'Germany (until 1990 former territory of the FRG)': 'Germany'})

# %% [markdown]
# pivedu

# %%
pivedu = pivedu.dropna()

# %%
pivedu.rank(ascending = False, method = 'first').head()
# Out:
# TIME            2006.0  2007.0  2008.0  2009.0  2010.0  2011.0
# GEO
# Austria           10.0     7.0    11.0     7.0     8.0     8.0
# Belgium            5.0     4.0     3.0     4.0     5.0     5.0
# Bulgaria          21.0    21.0    20.0    20.0    22.0    22.0
# Cyprus             2.0     2.0     2.0     2.0     2.0     3.0
# Czech Republic    19.0    20.0    21.0    21.0    20.0    19.0

# %%
totalsum = pivedu.sum(axis=1)
totalsum.rank(ascending = False, method = 'dense').sort_values().head()
# Out:
# GEO
# Denmark    1.0
# Cyprus     2.0
# Finland    3.0
# Malta      4.0
# Belgium    5.0
# dtype: float64

# %%
totalsum = pivedu.sum(axis = 1).sort_values(ascending = False)
totalsum.plot(kind = 'bar', style = 'b', alpha = 0.4, 
              title = "Total Values for Country")
# Out:
# <Axes: title={'center': 'Total Values for Country'}, xlabel='GEO'>

# %%
my_colors = ['b', 'r', 'g', 'y', 'c', 'm']
ax = pivedu.plot(kind = 'barh',
                stacked = False,
                color = my_colors)
ax.legend(loc = 'center right', bbox_to_anchor = (1, .5))

# %%
ax = pivedu.plot(kind = 'barh',
                stacked = True,
                title = 'Values for Country',
                color = my_colors)
ax.legend(loc = 'center right', bbox_to_anchor = (1, .5))

# %% [markdown]
# totalsum = pivedu.sum(axis = 1).sort_values(ascending = False)
# totalsum.plot(kind = 'bar', style = 'b', alpha = 0.4,
#               title = "Total Values for Country")
